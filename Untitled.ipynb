# %%
import sys
import os
import importlib
import matplotlib.pyplot as plt
import main
# Ensure the repo is in the path
repo_path = os.path.abspath("MLinfe_edge")  # adjust as needed
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

# %matplotlib inline

importlib.reload(main)
main.main()
# Out:
# edge_num:   3
# first request set:   <main.Request_set object at 0x126358440>
# Total Requests: 290
# Completed Requests: 290
# Rejected Requests: 0
# Difference between finish time of completed request and deadline, for all request sets:   15.469260773864152
# Difference between average accuracy of completed request and expected minimum accuracy, for request sets with completed requests:   3.543000000000003
# Average Total Time per Request: 2.21 seconds
# 90th Percentile Response Time: 4.07 seconds
# 95th Percentile Response Time: 4.56 seconds
# Total Energy Consumed: 10792.53
# Node 0 FLOPs Utilization: 84.85%
# Node 1 FLOPs Utilization: 28.28%
# Node 2 FLOPs Utilization: 0.00%
