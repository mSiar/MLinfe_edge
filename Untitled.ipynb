# %%
import sys
import os
import importlib
import matplotlib.pyplot as plt
import main

repo_path = os.path.abspath("MLinfe_edge") 
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

# %matplotlib inline

importlib.reload(main)
main.main()
# Out:
# i:   1597
# first request set:   <main.Request_set object at 0x309432b40>
# Total Requests: 15970
# Completed Requests: 14430
# Rejected Requests: 1540
# Difference between finish time of completed request and deadline, for all request sets:   5199924.06085651
# Difference between average accuracy of completed request and expected minimum accuracy, for request sets with completed requests:   189.30700000000016
# Average Total Time per Request: 1.22 seconds
# 90th Percentile Response Time: 2.64 seconds
# 95th Percentile Response Time: 3.02 seconds
# Total Energy Consumed: 4633.34
# Node 0 FLOPs Utilization: 56.57%
# Node 1 FLOPs Utilization: 0.00%
# Node 2 FLOPs Utilization: 0.00%
# Node 3 FLOPs Utilization: 0.00%
# Node 4 FLOPs Utilization: 0.00%
# first request set:   <main.Request_set object at 0x34e7cc770>
# Total Requests: 15970
# Completed Requests: 1443
# Rejected Requests: 14527
# ...
