# %%
import sys
import os
import importlib
import matplotlib.pyplot as plt
import main
import setting
import pandas as pd
# Ensure the repo is in the path
repo_path = os.path.abspath("MLinfe_edge")  # adjust as needed
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

# %matplotlib inline
importlib.reload(setting)
importlib.reload(main)
main.main(False)
# Out:
# energy_scale:   [7, 2, 2, 7, 4]
# /Users/hsiar/Documents/Eval/venv/MLinfe_edge/main.py:433: RuntimeWarning: divide by zero encountered in scalar divide
#   service_time = ctn["service_time"]
# /Users/hsiar/Documents/Eval/venv/MLinfe_edge/main.py:436: RuntimeWarning: invalid value encountered in scalar divide
#   var_inter = np.var(inter_arrival_times) if len(inter_arrival_times) > 1 else 0
# ---------------------------  Approach:  Energy-aware  ---------------------------------
# Total Requests: 50380
# Completed Requests: 4513
# Rejected Requests: 36447
# Difference between finish time of completed request and deadline, for all request sets:   3485.0633530805085
# Difference between average accuracy of completed request and expected minimum accuracy, for request sets with completed requests:   41.500000000000014
# Average Total Time per Request: 0.18 seconds
# 90th Percentile Response Time: 4.63 seconds
# 95th Percentile Response Time: 6.38 seconds
# Total Energy Consumed: 11327.07
# node: 0 used this much energy: 4268.703703638166
# node: 0 energy limit:  6148800
# Node 0 Avg FLOPs Utilization: 0.8843310577683481
# node: 1 used this much energy: 3017.5659824241884
# node: 1 energy limit:  2628000
# Node 1 Avg FLOPs Utilization: 0.9158650114020462
# node: 2 used this much energy: 2880.5047318593133
# node: 2 energy limit:  1404000
# Node 2 Avg FLOPs Utilization: 0.9378569724449545
# node: 3 used this much energy: 117.20234916824847
# node: 3 energy limit:  7560000
# Node 3 Avg FLOPs Utilization: 0.9913855514339455
# node: 4 used this much energy: 1043.0926594058983
# node: 4 energy limit:  3600000
# Node 4 Avg FLOPs Utilization: 0.9727173200892788
# AVERAGE TOTAL UTILIZATION:   0.9404311826277146
# Average Decision Time per Slot: 0.0000 seconds
# 90th Percentile Decision Time: 0.0001 seconds
# Saved response logs to Energy-aware_response_logs.csv
# ---------------------------  Approach:  Deadline-energy-aware  ---------------------------------
# Total Requests: 50380
# Completed Requests: 8224
# Rejected Requests: 32736
# Difference between finish time of completed request and deadline, for all request sets:   5927.10309469723
# Difference between average accuracy of completed request and expected minimum accuracy, for request sets with completed requests:   80.56000000000003
# Average Total Time per Request: 0.41 seconds
# 90th Percentile Response Time: 5.71 seconds
# 95th Percentile Response Time: 8.06 seconds
# Total Energy Consumed: 26111.60
# node: 0 used this much energy: 14812.0679010842
# node: 0 energy limit:  6148800
# Node 0 Avg FLOPs Utilization: 0.811251996720474
# node: 1 used this much energy: 7223.812316757161
# node: 1 energy limit:  2628000
# Node 1 Avg FLOPs Utilization: 0.8908529311674899
# node: 2 used this much energy: 2891.053627759684
# node: 2 energy limit:  1404000
# Node 2 Avg FLOPs Utilization: 0.9368409005860275
# node: 3 used this much energy: 117.20234916824847
# node: 3 energy limit:  7560000
# Node 3 Avg FLOPs Utilization: 0.9913855514339455
# node: 4 used this much energy: 1067.4608904533088
# node: 4 energy limit:  3600000
# Node 4 Avg FLOPs Utilization: 0.9722508232119741
# AVERAGE TOTAL UTILIZATION:   0.9205164406239822
# Average Decision Time per Slot: 0.0000 seconds
# 90th Percentile Decision Time: 0.0001 seconds
# Saved response logs to Deadline-energy-aware_response_logs.csv
# ---------------------------  Approach:  Multi-criteria  ---------------------------------
# Total Requests: 50380
# Completed Requests: 40960
# Rejected Requests: 0
# Difference between finish time of completed request and deadline, for all request sets:   37149.30202285683
# Difference between average accuracy of completed request and expected minimum accuracy, for request sets with completed requests:   415.58000000000015
# Average Total Time per Request: 0.93 seconds
# 90th Percentile Response Time: 2.45 seconds
# 95th Percentile Response Time: 3.49 seconds
# Total Energy Consumed: 55857.37
# node: 0 used this much energy: 0
# node: 0 energy limit:  6148800
# Node 0 Avg FLOPs Utilization: 0.0
# node: 1 used this much energy: 0
# node: 1 energy limit:  2628000
# Node 1 Avg FLOPs Utilization: 0.0
# node: 2 used this much energy: 3286.195583601482
# node: 2 energy limit:  1404000
# Node 2 Avg FLOPs Utilization: 0.026738796869190742
# node: 3 used this much energy: 50972.461290864274
# node: 3 energy limit:  7560000
# Node 3 Avg FLOPs Utilization: 0.32394744522718716
# node: 4 used this much energy: 1598.7123947064392
# node: 4 energy limit:  3600000
# Node 4 Avg FLOPs Utilization: 0.702035655765996
# AVERAGE TOTAL UTILIZATION:   0.21054437957247477
# Average Decision Time per Slot: 0.0001 seconds
# 90th Percentile Decision Time: 0.0002 seconds
# Saved response logs to Multi-criteria_response_logs.csv

# %%
markers = ['o', 's', '^', 'v', '*']
ax_text = ['a', 'b', 'c', 'd', 'e']
y_fields = {
    "success_ratio": "Completed / Total Requests",
    "Speed:Deadline-Finish": "Response Time speed up (second)",
    "Acc:AvgAcc-ExpAcc": "Accuracy improvement",
    "Total_energy_used": "Total Energy Used (Watt)",
    "Total_utilisation": "Average Utilization"
}


arrival_log = pd.read_csv("log_diffArrv.csv")  # change path if needed
arrival_log["success_ratio"] = arrival_log["Completed_requests"] / (arrival_log["Completed_requests"] + arrival_log["Rejected_requests"])
approaches = arrival_log["approach"].unique()
fig, axs = plt.subplots(1, len(y_fields), figsize=(20, 4), sharey=False)
for i, (field, ylabel) in enumerate(y_fields.items()):
    ax = axs[i]
    for j, approach in enumerate(approaches):
        subset = arrival_log[arrival_log["approach"] == approach].sort_values("Arrival_rate")
        linewidth = 3 if approach == "Energy-aware" else 1.2
        ax.plot(
            subset["Arrival_rate"], subset[field],
            label=approach,
            marker=markers[j],
            linestyle='-', linewidth=linewidth
        )
    ax.set_xlabel(f"({ax_text[i]}) Arrival Rate")
    ax.set_ylabel(ylabel)
    # ax.set_xlim(ax.get_xlim()[::-1])
    ax.grid(True)
axs[0].legend(loc='best')
plt.tight_layout()
plt.savefig("Results_diffArrival.png", dpi=300, bbox_inches='tight')  # high quality
plt.show()


edge_log = pd.read_csv("log_diffEdge.csv") 
edge_log["success_ratio"] = edge_log["Completed_requests"] / (edge_log["Completed_requests"] + edge_log["Rejected_requests"])
approaches = edge_log["approach"].unique()
fig, axs = plt.subplots(1, len(y_fields), figsize=(20, 4), sharey=False)
for i, (field, ylabel) in enumerate(y_fields.items()):
    ax = axs[i]
    for j, approach in enumerate(approaches):
        subset = edge_log[edge_log["approach"] == approach].sort_values("edge_num")
        linewidth = 3 if approach == "Energy-aware" else 1.2
        ax.plot(
            subset["edge_num"], subset[field],
            label=approach,
            marker=markers[j],
            linestyle='-', 
            linewidth=linewidth
        )
    ax.set_xlabel(f"({ax_text[i]}) Number of edge servers")
    ax.set_ylabel(ylabel)
    ax.grid(True)
axs[0].legend(loc='best')
plt.tight_layout()
plt.savefig("Results_diffEdge.png", dpi=300, bbox_inches='tight')  # high quality
plt.show()


energy_log = pd.read_csv("log_diffEnergy.csv") 
energy_log["success_ratio"] = energy_log["Completed_requests"] / (energy_log["Completed_requests"] + energy_log["Rejected_requests"])
approaches = energy_log["approach"].unique()

unique_intervals = sorted(energy_log["Energy_interval"].unique())
interval_map = {interval: idx + 1 for idx, interval in enumerate(unique_intervals)}
energy_log["Energy_interval"] = energy_log["Energy_interval"].map(interval_map)

fig, axs = plt.subplots(1, len(y_fields), figsize=(20, 4), sharey=False)
for i, (field, ylabel) in enumerate(y_fields.items()):
    ax = axs[i]
    for j, approach in enumerate(approaches):
        subset = energy_log[energy_log["approach"] == approach].sort_values("Energy_interval")
        linewidth = 3 if approach == "Energy-aware" else 1.2
        ax.plot(
            subset["Energy_interval"], subset[field],
            label=approach,
            marker=markers[j],
            linestyle='-', 
            linewidth=linewidth
        )

    ax.set_xticks(list(interval_map.values()))
    ax.set_xticklabels(list(interval_map.keys()), rotation=45, ha='right')
    
    ax.set_xlabel(f"({ax_text[i]}) Energy limit of edge servers")
    ax.set_ylabel(ylabel)
    ax.grid(True)
axs[0].legend(loc='best')
plt.tight_layout()
plt.savefig("Results_diffEnergy.png", dpi=300, bbox_inches='tight')  # high quality
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

log_files = {
    "Energy-aware": "Energy-aware_response_logs.csv",
    "Deadline-energy-aware": "Deadline-energy-aware_response_logs.csv",
    "Multi-criteria": "Multi-criteria_response_logs.csv"
}

ax_text = ['a', 'b']

model_counts = {}
node_counts= {}

for approach, file in log_files.items():
    df = pd.read_csv(file)
    counts_model = df["model"].value_counts()
    model_counts[approach] = counts_model

    counts_node = df["edge_node_id"].value_counts()
    node_counts[approach] = counts_node

assigned_model = pd.DataFrame(model_counts).fillna(0).astype(int).sort_index()
assigned_node = pd.DataFrame(node_counts).fillna(0).astype(int).sort_index()

fig, axs = plt.subplots(1, 2, figsize=(20, 5), sharey=False)
assigned_model.plot(kind='bar', ax=axs[0])

axs[0].set_title("Request assignment per DNN model in each approach")
axs[0].set_xlabel("(a) Model variants")
axs[0].set_ylabel("Number of Assigned Requests")
axs[0].legend(title="Approach")
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

assigned_node.plot(kind='bar', ax=axs[1])
axs[1].set_title("Requests assignment per edge server in each approach")
axs[1].set_xlabel("(b) Edge servers")
axs[1].set_ylabel("Number of Assigned Requests")
axs[1].legend(title="Approach")
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.savefig("Results_perRequest.png", dpi=300, bbox_inches='tight')  # high quality
plt.show()
